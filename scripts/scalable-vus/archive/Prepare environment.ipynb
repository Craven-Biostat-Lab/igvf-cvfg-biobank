# %% [markdown]
# Things that need to run every time the analysis environment is re-created.

# %%
# !pip install scikit-survival

# %%
# !git clone https://github.com/Craven-Biostat-Lab/igvf-cvfg-biobank.git

# %%
# !pip install -e igvf-cvfg-biobank

# %% [markdown]
# For updating the installed package:

# %%
# !cd igvf-cvfg-biobank; git pull

# %%
rm -rf igvf-cvfg-biobank
